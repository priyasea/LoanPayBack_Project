# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LogisticRegression
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ### 🧭 Previewing the Dataset
# Displays the first few rows to understand structure and values.

# %%
df.head()
# Out:
#    id  annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0   0       29367.99                 0.084           736      2528.42
# 1   1       22108.02                 0.166           636      4593.10
# 2   2       49566.20                 0.097           694     17005.15
# 3   3       46858.25                 0.065           533      4682.48
# 4   4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender marital_status education_level employment_status  \
# 0          13.67  Female         Single     High School     Self-employed
# 1          12.92    Male        Married        Master's          Employed
# 2           9.76    Male         Single     High School          Employed
# 3          16.10  Female         Single     High School          Employed
# 4          10.21    Male        Married     High School          Employed
#
#          loan_purpose grade_subgrade  loan_paid_back
# 0               Other             C3             1.0
# 1  Debt consolidation             D3             0.0
# 2  Debt consolidation             C5             1.0
# 3  Debt consolidation             F1             1.0
# 4               Other             D1             1.0

# %% [markdown]
# ### 🔍 Checking Data Types
# Shows column types for preprocessing decisions.

# %%
df.dtypes
# Out:
# id                        int64
# annual_income           float64
# debt_to_income_ratio    float64
# credit_score              int64
# loan_amount             float64
# interest_rate           float64
# gender                   object
# marital_status           object
# education_level          object
# employment_status        object
# loan_purpose             object
# grade_subgrade           object
# loan_paid_back          float64
# dtype: object

# %% [markdown]
# ### 🚫 Missing Values Analysis
# Counts missing values to plan data cleaning.

# %%
df.isnull().sum()
# Out:
# id                      0
# annual_income           0
# debt_to_income_ratio    0
# credit_score            0
# loan_amount             0
# interest_rate           0
# gender                  0
# marital_status          0
# education_level         0
# employment_status       0
# loan_purpose            0
# grade_subgrade          0
# loan_paid_back          0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 📈 Statistical Summary
# Describes numerical columns to detect outliers and skew.

# %%
df.describe()
# Out:
#                   id  annual_income  debt_to_income_ratio   credit_score  \
# count  593994.000000  593994.000000         593994.000000  593994.000000
# mean   296996.500000   48212.202976              0.120696     680.916009
# std    171471.442235   26711.942078              0.068573      55.424956
# min         0.000000    6002.430000              0.011000     395.000000
# 25%    148498.250000   27934.400000              0.072000     646.000000
# 50%    296996.500000   46557.680000              0.096000     682.000000
# 75%    445494.750000   60981.320000              0.156000     719.000000
# max    593993.000000  393381.740000              0.627000     849.000000
#
#          loan_amount  interest_rate  loan_paid_back
# count  593994.000000  593994.000000   593994.000000
# mean    15020.297629      12.356345        0.798820
# std      6926.530568       2.008959        0.400883
# min       500.090000       3.200000        0.000000
# 25%     10279.620000      10.990000        1.000000
# 50%     15000.220000      12.370000        1.000000
# 75%     18858.580000      13.680000        1.000000
# max     48959.950000      20.990000        1.000000

# %% [markdown]
# ### 🏷️ Dropping Non-Predictive Columns
# Removes the id column as it adds no value.

# %%
df = df.drop('id' , axis = 1)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)
numerical_columns = list(df.dtypes[df.dtypes != 'object'].index)

# %% [markdown]
# <b> Bringing all columns in lowercase </b>

# %%
for c in categorical_columns:
    df[c] = df[c].str.lower().str.replace(' ', '_')

# %%
if 'loan_paid_back' in numerical_columns:
    numerical_columns.remove('loan_paid_back')

for col in numerical_columns:
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=30, color='gold', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
df.head()
# Out:
#    annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0       29367.99                 0.084           736      2528.42
# 1       22108.02                 0.166           636      4593.10
# 2       49566.20                 0.097           694     17005.15
# 3       46858.25                 0.065           533      4682.48
# 4       25496.70                 0.053           665     12184.43
#
#    interest_rate  gender marital_status education_level employment_status  \
# 0          13.67  female         single     high_school     self-employed
# 1          12.92    male        married        master's          employed
# 2           9.76    male         single     high_school          employed
# 3          16.10  female         single     high_school          employed
# 4          10.21    male        married     high_school          employed
#
#          loan_purpose grade_subgrade  loan_paid_back
# 0               other             c3             1.0
# 1  debt_consolidation             d3             0.0
# 2  debt_consolidation             c5             1.0
# 3  debt_consolidation             f1             1.0
# 4               other             d1             1.0

# %% [markdown]
# <b> Checking Unique values in columns

# %%
df.nunique()
# Out:
# annual_income           119728
# debt_to_income_ratio       526
# credit_score               399
# loan_amount             111570
# interest_rate             1454
# gender                       3
# marital_status               4
# education_level              5
# employment_status            5
# loan_purpose                 8
# grade_subgrade              30
# loan_paid_back               2
# dtype: int64

# %% [markdown]
# <b> Shape of Dataset

# %%
df.shape
# Out:
# (593994, 12)

# %% [markdown]
# <b> Analyzing categorical variables

# %%
df_grouped = df.groupby('education_level')['education_level'].count()

df_grouped
# Out:
# education_level
# bachelor's     279606
# high_school    183592
# master's        93097
# other           26677
# phd             11022
# Name: education_level, dtype: int64

# %%
df_grouped = df.groupby('loan_purpose')['loan_purpose'].count()

df_grouped
# Out:
# loan_purpose
# business               35303
# car                    58108
# debt_consolidation    324695
# education              36641
# home                   44118
# medical                22806
# other                  63874
# vacation                8449
# Name: loan_purpose, dtype: int64

# %%
df_grouped = df.groupby('grade_subgrade')['grade_subgrade'].count()

df_grouped
# Out:
# grade_subgrade
# a1     1600
# a2     2018
# a3     2066
# a4     1701
# a5     2471
# b1    14344
# b2    15167
# b3    13926
# b4    13877
# b5    13937
# c1    53363
# c2    54443
# c3    58695
# c4    55957
# c5    53317
# d1    37029
# d2    34432
# d3    36694
# d4    35097
# d5    32101
# e1     6891
# e2     6372
# e3     7075
# e4     8036
# e5     6084
# f1     5534
# f2     5203
# f3     5082
# f4     5535
# f5     5947
# Name: grade_subgrade, dtype: int64

# %%
df_grouped = df.groupby('employment_status')['employment_status'].count()

df_grouped
# Out:
# employment_status
# employed         450645
# retired           16453
# self-employed     52480
# student           11931
# unemployed        62485
# Name: employment_status, dtype: int64

# %% [markdown]
# <b> Train Test Split . We will split the df_full_train further later on after we complete EDA, hence commented rest of code

# %%
from sklearn.model_selection import train_test_split
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
#df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

#df_train = df_train.reset_index(drop=True)
#df_val = df_val.reset_index(drop=True)
#df_test = df_test.reset_index(drop=True)
#y_train = df_train.loan_paid_back.values
#y_val = df_val.loan_paid_back.values
#y_test = df_test.loan_paid_back.values

#del df_train['loan_paid_back']
#del df_val['loan_paid_back']
#del df_test['loan_paid_back']

# %%
#len(df_train), len(df_val), len(df_test)

# %%
numerical_columns
# Out:
# ['annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate']

# %%
categorical_columns
# Out:
# ['gender',
#  'marital_status',
#  'education_level',
#  'employment_status',
#  'loan_purpose',
#  'grade_subgrade']

# %% [markdown]
# <b> Both Genders have paid back the loan equally, hence not very imp feature

# %%
df_grouped = df_full_train.groupby('gender')['loan_paid_back'].mean()

df_grouped
# Out:
# gender
# female    0.801796
# male      0.795958
# other     0.797635
# Name: loan_paid_back, dtype: float64

# %% [markdown]
# <b> People irrespective of marital status have paid back loan, hence not important feature

# %%
df_grouped = df_full_train.groupby('marital_status')['loan_paid_back'].mean()

df_grouped
# Out:
# marital_status
# divorced    0.797757
# married     0.799305
# single      0.798968
# widowed     0.789344
# Name: loan_paid_back, dtype: float64

# %% [markdown]
# <b> Education Level has slight effect on loan paid back variable

# %%
df_grouped = df_full_train.groupby('education_level')['loan_paid_back'].mean()

df_grouped
# Out:
# education_level
# bachelor's     0.789271
# high_school    0.809445
# master's       0.803191
# other          0.801152
# phd            0.830204
# Name: loan_paid_back, dtype: float64

# %% [markdown]
# <b> Employment Status had major effect on loan paid back variable

# %%
df_grouped = df_full_train.groupby('employment_status')['loan_paid_back'].mean()

df_grouped
# Out:
# employment_status
# employed         0.894139
# retired          0.997432
# self-employed    0.898833
# student          0.262556
# unemployed       0.077512
# Name: loan_paid_back, dtype: float64

# %% [markdown]
# <b>Loan Purpose has not much effect on loan paid back variable hence not important feature</b>

# %%
df_grouped = df_full_train.groupby('loan_purpose')['loan_paid_back'].mean()

df_grouped
# Out:
# loan_purpose
# business              0.813167
# car                   0.799674
# debt_consolidation    0.797505
# education             0.777561
# home                  0.822732
# medical               0.776356
# other                 0.802105
# vacation              0.797554
# Name: loan_paid_back, dtype: float64

# %% [markdown]
# <b> Grade Subgrade does have some effect on loan paid back variable

# %%
df_grouped = df_full_train.groupby('grade_subgrade')['loan_paid_back'].mean()

df_grouped
# Out:
# grade_subgrade
# a1    0.951969
# a2    0.952584
# a3    0.956231
# a4    0.952518
# a5    0.945729
# b1    0.915150
# b2    0.938617
# b3    0.938836
# b4    0.932075
# b5    0.934884
# c1    0.860000
# c2    0.851475
# c3    0.835574
# c4    0.843796
# c5    0.846599
# d1    0.732926
# d2    0.722333
# d3    0.696985
# d4    0.715412
# d5    0.713410
# e1    0.650136
# e2    0.660066
# e3    0.641326
# e4    0.649395
# e5    0.667836
# f1    0.618833
# f2    0.619904
# f3    0.598776
# f4    0.642275
# f5    0.637018
# Name: loan_paid_back, dtype: float64

# %% [markdown]
# <b> Global Loan Paid Back

# %%
global_loan_paid_back = df_full_train['loan_paid_back'].mean()

global_loan_paid_back
# Out:
# np.float64(0.7989751575668936)

# %% [markdown]
# <b> 79% of people have paid back the loan - higly imbalanced data set

# %% [markdown]
# <b> Finiding Risk Ratio on All Categorical variables </b>

# %%
for c in categorical_columns:
    print(c)
    df_group = df_full_train.groupby(c).loan_paid_back.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_loan_paid_back 
    df_group['risk'] = df_group['mean'] / global_loan_paid_back 
    display(df_group)
    print()
    print()
# Out:
# gender
#             mean   count      diff      risk
# gender
# female  0.801796  244723  0.002821  1.003531
# male    0.795958  227512 -0.003017  0.996224
# other   0.797635    2960 -0.001340  0.998323
# marital_status
#                     mean   count      diff      risk
# marital_status
# divorced        0.797757   17034 -0.001218  0.998476
# married         0.799305  221635  0.000330  1.000413
# single          0.798968  231252 -0.000007  0.999991
# widowed         0.789344    5274 -0.009631  0.987946
# education_level
#                      mean   count      diff      risk
# education_level
# bachelor's       0.789271  223809 -0.009704  0.987855
# high_school      0.809445  146598  0.010470  1.013104
# master's         0.803191   74590  0.004216  1.005276
# other            0.801152   21358  0.002177  1.002724
# phd              0.830204    8840  0.031228  1.039086
# employment_status
#                        mean   count      diff      risk
# employment_status
# employed           0.894139  360613  0.095163  1.119107
# retired            0.997432   13239  0.198457  1.248389
# self-employed      0.898833   41891  0.099858  1.124982
# student            0.262556    9537 -0.536419  0.328616
# unemployed         0.077512   49915 -0.721463  0.097014
# loan_purpose
#                         mean   count      diff      risk
# loan_purpose
# business            0.813167   28282  0.014192  1.017763
# car                 0.799674   46594  0.000699  1.000874
# debt_consolidation  0.797505  259651 -0.001470  0.998160
# education           0.777561   29271 -0.021414  0.973198
# home                0.822732   35184  0.023757  1.029734
# medical             0.776356   18212 -0.022619  0.971690
# other               0.802105   51214  0.003130  1.003917
# vacation            0.797554    6787 -0.001421  0.998221
# grade_subgrade
#                     mean  count      diff      risk
# grade_subgrade
# a1              0.951969   1270  0.152993  1.191487
# a2              0.952584   1645  0.153608  1.192257
# a3              0.956231   1645  0.157256  1.196822
# a4              0.952518   1390  0.153543  1.192175
# a5              0.945729   1990  0.146753  1.183677
# b1              0.915150  11432  0.116175  1.145405
# b2              0.938617  12137  0.139642  1.174777
# b3              0.938836  11085  0.139861  1.175051
# b4              0.932075  11130  0.133100  1.166589
# b5              0.934884  11180  0.135909  1.170104
# c1              0.860000  42793  0.061025  1.076379
# c2              0.851475  43501  0.052500  1.065709
# c3              0.835574  47012  0.036599  1.045807
# c4              0.843796  44762  0.044821  1.056098
# c5              0.846599  42653  0.047624  1.059607
# d1              0.732926  29636 -0.066049  0.917333
# d2              0.722333  27515 -0.076642  0.904075
# d3              0.696985  29355 -0.101990  0.872349
# d4              0.715412  28023 -0.083563  0.895412
# d5              0.713410  25622 -0.085565  0.892907
# e1              0.650136   5505 -0.148839  0.813713
# e2              0.660066   5151 -0.138909  0.826141
# e3              0.641326   5643 -0.157650  0.802685
# e4              0.649395   6446 -0.149580  0.812785
# e5              0.667836   4844 -0.131139  0.835866
# f1              0.618833   4439 -0.180142  0.774534
# f2              0.619904   4170 -0.179071  0.775874
# f3              0.598776   4085 -0.200199  0.749430
# f4              0.642275   4414 -0.156701  0.803873
# f5              0.637018   4722 -0.161957  0.797294

# %%
from sklearn.metrics import mutual_info_score

# %%
def mutual_info_churn_score(series):
    return mutual_info_score(series, df_full_train.loan_paid_back)

# %%
mi = df_full_train[categorical_columns].apply(mutual_info_churn_score)
print(mi.sort_values(ascending=False))
# Out:
# employment_status    0.175917
# grade_subgrade       0.026748
# loan_purpose         0.000325
# education_level      0.000311
# gender               0.000026
# marital_status       0.000003
# dtype: float64

# %%
print(mi.sort_values(ascending=False))
# Out:
# employment_status    0.175917
# grade_subgrade       0.026748
# loan_purpose         0.000325
# education_level      0.000311
# gender               0.000026
# marital_status       0.000003
# dtype: float64

# %% [markdown]
# <b> Based on mutual information score we will drop gender , marital status fields from both training and test data sets

# %%
df_full_train = df_full_train.drop(['gender', 'marital_status'], axis = 1)

# %%
df_test = df_test.drop(['gender', 'marital_status'], axis = 1)

# %%
df_full_train['education_level'] = df_full_train['education_level'].replace("master's", "masters")

# %%
df_full_train['education_level'] = df_full_train['education_level'].replace("bachelor's", "bachelors")

# %%
df_test['education_level'] = df_test['education_level'].replace("master's", "masters")
df_test['education_level'] = df_test['education_level'].replace("bachelor's", "bachelors")

# %% [markdown]
# <b> Converting education level to numerical using Ordinal encoder

# %%
# Define the order of categories
edu_category_order = [['high_school', 'other', 'bachelors', 'masters', 'phd']]
edu_encoder = OrdinalEncoder(categories=edu_category_order)
df_full_train['education_encoded'] = edu_encoder.fit_transform(df_full_train[['education_level']])
df_test['education_encoded'] = edu_encoder.transform(df_test[['education_level']])
#print(df_full_train.head())

# %%
df_full_train.tail(10)
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 413825       24274.33                 0.088           669     25019.89
# 229520       53789.17                 0.120           750     16591.53
# 21440        69500.13                 0.044           666     12409.13
# 117583       29096.46                 0.138           708     23198.65
# 73349        64435.76                 0.078           709     27563.86
# 371403       51957.35                 0.086           681     12452.00
# 491263       20264.17                 0.160           652     18207.08
# 470924       25609.70                 0.053           664      1418.39
# 491755       39711.94                 0.262           638      9121.82
# 128037       23983.29                 0.091           569     10790.12
#
#         interest_rate education_level employment_status        loan_purpose  \
# 413825          12.83     high_school          employed                 car
# 229520           9.92       bachelors          employed                home
# 21440           15.00     high_school          employed  debt_consolidation
# 117583          13.17       bachelors     self-employed               other
# 73349           10.52     high_school          employed           education
# 371403          14.96       bachelors          employed  debt_consolidation
# 491263          12.17     high_school     self-employed  debt_consolidation
# 470924          12.66     high_school          employed  debt_consolidation
# 491755          11.20       bachelors          employed                home
# 128037          15.44         masters     self-employed  debt_consolidation
#
#        grade_subgrade  loan_paid_back  education_encoded
# 413825             d2             1.0                0.0
# 229520             b3             1.0                2.0
# 21440              d5             1.0                0.0
# 117583             c3             1.0                2.0
# 73349              c2             1.0                0.0
# 371403             c4             1.0                2.0
# 491263             d4             1.0                0.0
# 470924             d4             1.0                0.0
# 491755             d3             1.0                2.0
# 128037             f4             0.0                3.0

# %%
df_full_train = df_full_train.drop(['education_level','loan_purpose'], axis=1)

# %%
df_test = df_test.drop(['education_level','loan_purpose'], axis=1)

# %%
df_full_train.head()
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 105200       47868.15                 0.070           773     28644.19
# 436067       35444.49                 0.153           693     27775.31
# 385322       92914.49                 0.140           715     30784.02
# 464782       43761.69                 0.156           723      8181.09
# 468954       63671.48                 0.149           675     17626.06
#
#         interest_rate employment_status grade_subgrade  loan_paid_back  \
# 105200          10.16          employed             b2             1.0
# 436067          16.14          employed             c5             1.0
# 385322          12.35          employed             c4             1.0
# 464782          10.13          employed             c4             1.0
# 468954          12.60          employed             c3             1.0
#
#         education_encoded
# 105200                0.0
# 436067                0.0
# 385322                0.0
# 464782                4.0
# 468954                2.0

# %%
df_test.head()
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 566215       52233.83                 0.125           663      7454.22
# 123502       29247.24                 0.127           639     20391.28
# 367747       13802.88                 0.164           736     17984.01
# 359153       48758.31                 0.090           707     10209.48
# 440880       49816.42                 0.090           665     18123.14
#
#         interest_rate employment_status grade_subgrade  loan_paid_back  \
# 566215          14.89          employed             d2             1.0
# 123502          12.29        unemployed             d2             0.0
# 367747          11.00     self-employed             c5             1.0
# 359153          10.17          employed             c2             1.0
# 440880          16.06          employed             d4             1.0
#
#         education_encoded
# 566215                4.0
# 123502                0.0
# 367747                2.0
# 359153                2.0
# 440880                0.0

# %%
grade_category_order = [['f5', 'f4', 'f3', 'f2', 'f1', 'e5', 'e4','e3','e2','e1', 'd5', 'd4','d3','d2','d1', 'c5', 'c4','c3','c2','c1', 'b5', 'b4','b3','b2','b1',  'a5', 'a4','a3','a2','a1']]
grade_encoder = OrdinalEncoder(categories=grade_category_order)
df_full_train['grade_code'] = grade_encoder.fit_transform(df_full_train[['grade_subgrade']])
df_full_train  = df_full_train.drop(['grade_subgrade'], axis = 1)
df_test['grade_code'] = grade_encoder.transform(df_test[['grade_subgrade']])
df_test  = df_test.drop(['grade_subgrade'], axis = 1)

df_full_train.head()
# Out:
#         annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 105200       47868.15                 0.070           773     28644.19
# 436067       35444.49                 0.153           693     27775.31
# 385322       92914.49                 0.140           715     30784.02
# 464782       43761.69                 0.156           723      8181.09
# 468954       63671.48                 0.149           675     17626.06
#
#         interest_rate employment_status  loan_paid_back  education_encoded  \
# 105200          10.16          employed             1.0                0.0
# 436067          16.14          employed             1.0                0.0
# 385322          12.35          employed             1.0                0.0
# 464782          10.13          employed             1.0                4.0
# 468954          12.60          employed             1.0                2.0
#
#         grade_code
# 105200        23.0
# 436067        15.0
# 385322        16.0
# 464782        16.0
# 468954        17.0

# %%
numerical_columns = list(df.dtypes[df.dtypes != 'object'].index)
numerical_columns
# Out:
# ['annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'loan_paid_back']

# %%
df_full_train[numerical_columns].corrwith(df_full_train.loan_paid_back).abs()
# Out:
# annual_income           0.006148
# debt_to_income_ratio    0.335758
# credit_score            0.234319
# loan_amount             0.003521
# interest_rate           0.130789
# loan_paid_back          1.000000
# dtype: float64

# %% [markdown]
# <B> Analyzed numerical columns based

# %%
def analyzenumeric_cols(numerical_columns): 
    for n in numerical_columns:
        n_mean = df_full_train[n].mean()
        n_below_mean = df_full_train[df_full_train[n] <= n_mean].loan_paid_back.mean()
        n_above_mean = df_full_train[df_full_train[n] > n_mean].loan_paid_back.mean()
        print("For numeric column ", n, "loan paid back % below mean is ", n_below_mean)
        print("For numeric column ", n, "loan paid back % above mean is ", n_above_mean)

# %%
analyzenumeric_cols(numerical_columns)
# Out:
# For numeric column  annual_income loan paid back % below mean is  0.7961039885476562
# For numeric column  annual_income loan paid back % above mean is  0.8022409039182083
# For numeric column  debt_to_income_ratio loan paid back % below mean is  0.8815228762320478
# For numeric column  debt_to_income_ratio loan paid back % above mean is  0.658643848225548
# For numeric column  credit_score loan paid back % below mean is  0.715795716179446
# For numeric column  credit_score loan paid back % above mean is  0.8765592779836253
# For numeric column  loan_amount loan paid back % below mean is  0.801466426873593
# For numeric column  loan_amount loan paid back % above mean is  0.7964640659860727
# For numeric column  interest_rate loan paid back % below mean is  0.8421851547196052
# For numeric column  interest_rate loan paid back % above mean is  0.7563975617194975
# For numeric column  loan_paid_back loan paid back % below mean is  0.0
# For numeric column  loan_paid_back loan paid back % above mean is  1.0

# %% [markdown]
# <b> 1. So it shows that higher credit score implies person will pay back loan and  lower credit score implies person will not payback loan (positive correlation)
# <b> 2. So it shows that higher debttoincome ratio implies person will not pay back loan and  lower debttoincomee implies person will  payback loan
#     (negative Correlation)
# <b> 3. For lower interest_rate loan paid back percent is higher than higher interest rate (negative Correlation)
#
# <b> The other columns like Annual Income/Loan Amount does not really impact the Loan Pay Back intention

# %%
#This is also corroborated by Correlation table
df_full_train[numerical_columns].corrwith(df_full_train.loan_paid_back).abs().sort_values(ascending=False)
# Out:
# loan_paid_back          1.000000
# debt_to_income_ratio    0.335758
# credit_score            0.234319
# interest_rate           0.130789
# annual_income           0.006148
# loan_amount             0.003521
# dtype: float64

# %%
plt.figure(figsize=(10,8))
cor=df_full_train.corr(numeric_only=True)
sns.heatmap(cor, cmap='coolwarm', annot=True, fmt=".2f")
plt.show()

# %%
if 'loan_paid_back' in numerical_columns:
    numerical_columns.remove('loan_paid_back')

# %% [markdown]
# <b> Since we have done EDA, we will further split the dataset

# %%
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
y_train = df_train.loan_paid_back.values
y_val = df_val.loan_paid_back.values
y_test = df_test.loan_paid_back.values

del df_train['loan_paid_back']
del df_val['loan_paid_back']
del df_test['loan_paid_back']

# %%
df_train.head()
# Out:
#    annual_income  debt_to_income_ratio  credit_score  loan_amount  \
# 0       60737.14                 0.204           784      8243.98
# 1       52493.49                 0.076           689     14924.53
# 2       30887.15                 0.079           611      2274.98
# 3       48362.84                 0.053           715     25863.66
# 4       74599.93                 0.152           563      9995.24
#
#    interest_rate employment_status  education_encoded  grade_code
# 0           9.97          employed                0.0        20.0
# 1          13.91     self-employed                3.0        15.0
# 2          14.52          employed                0.0        12.0
# 3          11.74          employed                0.0        19.0
# 4          14.64          employed                0.0         2.0

# %%
categorical_columns = list(df_train.dtypes[df_train.dtypes == 'object'].index)

categorical_columns
# Out:
# ['employment_status']

# %%
numerical_columns = list(df_train.dtypes[df_train.dtypes != 'object'].index)

numerical_columns
# Out:
# ['annual_income',
#  'debt_to_income_ratio',
#  'credit_score',
#  'loan_amount',
#  'interest_rate',
#  'education_encoded',
#  'grade_code']

# %%
from sklearn.feature_extraction import DictVectorizer
dv = DictVectorizer(sparse=False)

train_dict = df_train[categorical_columns + numerical_columns].to_dict(orient='records')
X_train = dv.fit_transform(train_dict)

val_dict = df_val[categorical_columns + numerical_columns].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
log_model = LogisticRegression(solver='lbfgs')
# solver='lbfgs' is the default solver in newer version of sklearn
# for older versions, you need to specify it explicitly
log_model.fit(X_train, y_train)
# Out:
# C:\Users\Meera\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_model.intercept_[0]
# Out:
# np.float64(-0.030533861751577768)

# %%
log_model.coef_[0].round(3)
# Out:
# array([ 0.   ,  0.011, -0.201, -0.131,  1.534,  0.118,  0.184, -0.234,
#        -1.633, -0.089, -0.412, -0.   ])

# %%
y_pred = log_model.predict_proba(X_val)[:, 1]

# %%
loan_decision = (y_pred >= 0.5)

# %%
(y_val == loan_decision).mean()
# Out:
# np.float64(0.8687278512445391)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# np.float64(0.8108213730371027)

# %% [markdown]
# <b> LogisticRegression Model is giving Accuracy of 86% and roc_auc_score of 0.8108 on validation set

# %%
dicts_test = df_test[categorical_columns + numerical_columns].to_dict(orient='records')
X_test = dv.transform(dicts_test)
y_pred = log_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# <b> LogisticRegression Model is giving Accuracy of 86.8% and roc_auc_score of 0.816 on test set

# %%
auc_test_log  = roc_auc_score(y_test, y_pred)

# %%
test_loan_decision  = (y_pred >= 0.5)

# %%
(y_test == test_loan_decision).mean()
# Out:
# np.float64(0.868315389860184)

# %% [markdown]
# <B> Using Decision Tree best AUC is acheived at depth = 10

# %%
depths = [1, 2, 3, 4, 5, 6, 10, 15, 20, None]

for depth in depths: 
    dt = DecisionTreeClassifier(max_depth=depth)
    dt.fit(X_train, y_train)
    
    y_pred = dt.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred)
    
    print('%4s -> %.3f' % (depth, auc))
# Out:
#    1 -> 0.734
#    2 -> 0.832
#    3 -> 0.854
#    4 -> 0.889
#    5 -> 0.901
#    6 -> 0.906
#   10 -> 0.910
#   15 -> 0.882
#   20 -> 0.825
# None -> 0.771

# %% [markdown]
# <B> Trying to determine best min_samples_leaf at depths 5,6,10

# %%
scores = []
for d in [5,6,10]:
    for s in [1, 5, 10, 15, 20, 500, 100, 200]:
        dt = DecisionTreeClassifier(max_depth=d, min_samples_leaf=s)
        dt.fit(X_train, y_train)

        y_pred = dt.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred)
        
        scores.append((d, s, auc))

# %%
columns = ['max_depth', 'min_samples_leaf', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns=['max_depth'], values=['auc'])
df_scores_pivot
# Out:
#                        auc
# max_depth               5         6         10
# min_samples_leaf
# 1                 0.900763  0.906093  0.909762
# 5                 0.900763  0.906127  0.912045
# 10                0.900763  0.906117  0.912938
# 15                0.900763  0.906119  0.913367
# 20                0.900763  0.906117  0.913589
# 100               0.900765  0.906101  0.914155
# 200               0.900759  0.905977  0.913679
# 500               0.900795  0.905597  0.912861

# %% [markdown]
# <b> lets considder min_sample_leaves = 100 and max_depth = 10 as final parameters for the decision tree

# %%
dt = DecisionTreeClassifier(max_depth=10, min_samples_leaf=100)
dt.fit(X_train, y_train)
y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print("Auc with Decision tree of depth 10 and min sample leaves = 100 is", auc)
# Out:
# Auc with Decision tree of depth 10 and min sample leaves = 100 is 0.9141546209289892

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
n_estimators = [100, 200, 300]
max_features = ['sqrt', 'log2']
max_depth = [5, 6, 10]
min_samples_leaf = [20, 100, 200]

params_grid = {
    'n_estimators': n_estimators,
    'max_features': max_features,
    'max_depth': max_depth,
    'min_samples_leaf': min_samples_leaf
}

model_rf = RandomForestClassifier(random_state=42, n_jobs=-1)

model_cv = GridSearchCV(
    estimator=model_rf,
    param_grid=params_grid,
    scoring="roc_auc",
    cv=3,
    verbose=1,
    n_jobs=-1
)

model_cv.fit(X_train, y_train)

print("Best Parameters:", model_cv.best_params_)

best_model = model_cv.best_estimator_
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'n_estimators': 100}

# %%
pred = best_model.predict_proba(X_val)[:, 1]

# %%
auc = roc_auc_score(y_val, pred)

print(auc)
# Out:
# 0.9133764048411438

# %% [markdown]
# <b> We are achieving same accuracy with Randon Forest Also

# %%
def parse_xgb_output(output):
    results = []

    for line in output.stdout.strip().split('\n'):
        it_line, train_line, val_line = line.split('\t')

        it = int(it_line.strip('[]'))
        train = float(train_line.split(':')[1])
        val = float(val_line.split(':')[1])

        results.append((it, train, val))
    
    columns = ['num_iter', 'train_auc', 'val_auc']
    df_results = pd.DataFrame(results, columns=columns)
    return df_results

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\meera\anaconda3\lib\site-packages (3.1.1)
# Requirement already satisfied: numpy in c:\users\meera\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\meera\anaconda3\lib\site-packages (from xgboost) (1.15.3)

# %%
import xgboost as xgb

# %%
features = list(dv.get_feature_names_out())
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)
dtest = xgb.DMatrix(X_test, label=y_test, feature_names=features)

# %%
from sklearn.model_selection import RandomizedSearchCV

params = {
    "max_depth": [ 5, 6,10],
    "min_child_weight": [1, 6,10,30],
    "learning_rate": [0.01, 0.05, 0.1, 0.2],
}
search = RandomizedSearchCV(
    estimator=xgb.XGBClassifier(),
    param_distributions=params,
    n_iter=200,
    scoring="roc_auc",
    cv=3,
    verbose=1,
    n_jobs=-1
)
search.fit(X_train, y_train)
print(search.best_params_)
# Out:
# C:\Users\Meera\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 48 is smaller than n_iter=200. Running 48 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# {'min_child_weight': 30, 'max_depth': 6, 'learning_rate': 0.2}

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
# %%capture output

xgb_params = {
    'eta': 0.2, 
    'max_depth': 6,
    'min_child_weight': 30,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

xgb_model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
s = output.stdout

# %%
df_score = parse_xgb_output(output)

# %%
df_score
# Out:
#     num_iter  train_auc  val_auc
# 0          0    0.90647  0.90603
# 1          5    0.91206  0.91136
# 2         10    0.91396  0.91329
# 3         15    0.91537  0.91456
# 4         20    0.91604  0.91514
# 5         25    0.91709  0.91583
# 6         30    0.91794  0.91634
# 7         35    0.91846  0.91657
# 8         40    0.91919  0.91705
# 9         45    0.92002  0.91768
# 10        50    0.92079  0.91820
# 11        55    0.92104  0.91830
# 12        60    0.92160  0.91851
# 13        65    0.92222  0.91879
# 14        70    0.92273  0.91905
# 15        75    0.92333  0.91939
# 16        80    0.92380  0.91963
# 17        85    0.92414  0.91969
# 18        90    0.92447  0.91976
# 19        95    0.92493  0.91995
# 20       100    0.92561  0.92031
# 21       105    0.92589  0.92042
# 22       110    0.92618  0.92048
# 23       115    0.92649  0.92067
# 24       120    0.92679  0.92073
# 25       125    0.92719  0.92085
# 26       130    0.92746  0.92083
# 27       135    0.92780  0.92084
# 28       140    0.92810  0.92096
# 29       145    0.92830  0.92102
# 30       150    0.92855  0.92100
# 31       155    0.92879  0.92106
# 32       160    0.92899  0.92102
# 33       165    0.92931  0.92120
# 34       170    0.92946  0.92120
# 35       175    0.92972  0.92132
# 36       180    0.92988  0.92132
# 37       185    0.93009  0.92131
# 38       190    0.93030  0.92139
# 39       195    0.93050  0.92135
# 40       199    0.93063  0.92135

# %%
##best Auc is acheoved at iteration number 190

# %%
plt.plot(df_score.num_iter, df_score.train_auc, label='train')
plt.plot(df_score.num_iter, df_score.val_auc, label='val')
plt.legend()
plt.show()

# %%
test_pred = xgb_model.predict(dtest)

# %%
test_pred
# Out:
# array([0.8903159 , 0.0058043 , 0.9585007 , ..., 0.9349672 , 0.99087334,
#        0.9817587 ], dtype=float32)

# %%
roc_auc_score(y_test, test_pred)
# Out:
# np.float64(0.9210320425561647)

# %%
##So considering the final model as XGB Boost

# %%
#Saving the model
